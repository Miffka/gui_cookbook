# %%
# imports
import tkinter as tk
from tkinter import ttk
# creating a window
win = tk.Tk()
# window title
win.title('Python GUI')
# make it unresizable
win.resizable(0,0)
# Add a label
ttk.Label(win, text='A label').grid(column=0, row=0)
# Start a GUI loop
win.mainloop()

# %%
# imports
import tkinter as tk
from tkinter import ttk

# creating a window
win = tk.Tk()
# window title
win.title('Python GUI')
# make it unresizable
win.resizable(0,0)
# Modify adding a label
aLabel = ttk.Label(win, text='A Label')
aLabel.grid(column=0, row=0)
# Button Click Event Callback Function
def clickMe():
    action.configure(text='** I have been clicked! **')
    aLabel.configure(foreground='red')
# Adding a Button
action = ttk.Button(win, text='Click Me!', command=clickMe)
action.grid(column=1, row=0)
win.mainloop()

# %%
# imports
import tkinter as tk
from tkinter import ttk

# creating a window
win = tk.Tk()
# window title
win.title('Python GUI')
# make it unresizable
win.resizable(0,0)

# Adding a label
ttk.Label(win, text='Enter your name: ').grid(column=0, row=0)
# Button Click Event Callback Function
def clickMe():
    action.configure(text='Hello ' + name.get() + '!')
# Adding a Button
action = ttk.Button(win, text='Click Me!', command=clickMe)
action.grid(column=1, row=1)

# Adding a textbook entry widget
name = tk.StringVar()
nameEntered = ttk.Entry(win, width=12, textvariable=name)
nameEntered.grid(column=0, row=1)

win.mainloop()

# %%
# imports
import tkinter as tk
from tkinter import ttk

# creating a window
win = tk.Tk()
# window title
win.title('Python GUI')
# make it unresizable
win.resizable(0,0)

# Adding a label
ttk.Label(win, text='Enter your name: ').grid(column=0, row=0)
# Button Click Event Callback Function
def clickMe():
    action.configure(text='Hello ' + name.get() + '!')
# Adding a Button
action = ttk.Button(win, text='Click Me!', command=clickMe)
action.grid(column=1, row=1)
action.configure(state='disabled')

# Adding a textbook entry widget
name = tk.StringVar()
nameEntered = ttk.Entry(win, width=12, textvariable=name)
nameEntered.grid(column=0, row=1)
# Focus on widget
nameEntered.focus()

win.mainloop()

# %%
# imports
import tkinter as tk
from tkinter import ttk

# creating a window
win = tk.Tk()
# window title
win.title('Python GUI')
# make it unresizable
win.resizable(0,0)

# Adding a label
ttk.Label(win, text='Enter your name: ').grid(column=0, row=0)
# Button Click Event Callback Function
def clickMe():
    action.configure(text=name.get() + ', you are in love with ' + number.get())
# Adding a Button
action = ttk.Button(win, text='Click Me!', command=clickMe)
action.grid(column=2, row=1)

# Adding a textbook entry widget
name = tk.StringVar()
nameEntered = ttk.Entry(win, width=12, textvariable=name)
nameEntered.grid(column=0, row=1)

# Adding combo box widget
ttk.Label(win, text='Choose a number: ').grid(column=1, row=0)
number = tk.StringVar()
numberChosen = ttk.Combobox(win, width=12, textvariable=number)
numberChosen['values'] = (1,2,4,100)
numberChosen.grid(column=1, row=1)
numberChosen.current(0)

win.mainloop()
